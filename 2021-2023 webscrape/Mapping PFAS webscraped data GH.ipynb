# %% [markdown]
# ### This notebook creates a map that displays military base locations that exceed EPA's PFAS guidelines of 4 parts per trillion (ppt)

# %%
import os
import pandas as pd
import plotly.express as px
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt

os.chdir(r'C:\Users\OITNYNWilsoS\OneDrive - Department of Veterans Affairs\python\PACT Act - MET/')
cwd = os.getcwd()
print("Current working directory is:", cwd)
# Out:
# Current working directory is: C:\Users\OITNYNWilsoS\OneDrive - Department of Veterans Affairs\python\PACT Act - MET

# %%
#removing store magic and pulling data in via csv instead for GitHub
#lsmagic
#%store -r 
#exceed
#%store -r
#metadata_df

# %%
#exceed_geo = exceed.merge(metadata_df.rename({'InstallationName': 'FinalData.InstallationName'}, axis=1), on='FinalData.InstallationName', how='left', indicator=True)
#exceed_geo.head()
#exceed_geo.to_csv('exceed_geo_all.csv', index='False')

# %%
url = 'https://github.com/plain-jane-gray/PFAS-webscrape/blob/main/exceed_geo_all.csv?raw=true'
exceed_geo = pd.read_csv(url)
exceed_geo.head()
# Out:
#    Unnamed: 0  FinalData.Id FinalData.Component FinalData.InstallationName  \
# 0           0      123477.0           Air Force         Air Force Plant 44
# 1           1      123501.0           Air Force         Air Force Plant 44
# 2           2       24112.0           Air Force                 Arnold AFB
# 3           3       24113.0           Air Force                 Arnold AFB
# 4           4       24136.0           Air Force                 Arnold AFB
#
#   FinalData.InstallationType       FinalData.SampleDate  \
# 0                     Active  2022-10-11T00:00:00-04:00
# 1                     Active  2022-10-11T00:00:00-04:00
# 2                     Active  2021-12-14T00:00:00-05:00
# 3                     Active  2021-12-14T00:00:00-05:00
# 4                     Active  2021-12-14T00:00:00-05:00
#
#   FinalData.AnalysisMethod FinalData.AnalyteAbbrev  FinalData.FinalResult  \
# 0                  QSM_B15                    PFOS                   29.2
# 1                  QSM_B15                    PFOS                   28.5
# 2                  QSM_B15                    PFOS                   13.9
# 3                  QSM_B15                    PFOA                   39.2
# 4                  QSM_B15                    PFOS                   14.3
#
#    MCLs  ...  FinalData.TreatmentSystem  FinalData.PreOrPostTreatment  Id  \
# 0     4  ...                        Yes                 pre-treatment  24
# 1     4  ...                        Yes                 pre-treatment  24
# 2     4  ...                         No                           NaN  41
# 3     4  ...                         No                           NaN  41
# 4     4  ...                         No                           NaN  41
#
#   DodComponentId DodComponent      State  InstallationType   Latitude  \
# 0           5700    Air Force    Arizona            Active  32.221743
# 1           5700    Air Force    Arizona            Active  32.221743
# 2           5700    Air Force  Tennessee            Active  35.398810
# 3           5700    Air Force  Tennessee            Active  35.398810
# 4           5700    Air Force  Tennessee            Active  35.398810
#
#     Longitude _merge
# 0 -110.926479   both
# 1 -110.926479   both
# 2  -86.078066   both
# 3  -86.078066   both
# 4  -86.078066   both
#
# [5 rows x 24 columns]

# %%
#filterning to only needed columns and dropping duplicates
exceed_geo = exceed_geo[['FinalData.Component',
                         'FinalData.InstallationName',
                         'State',
                         'Latitude',
                         'Longitude']]

exceed_geo = exceed_geo.drop_duplicates()
exceed_geo.reset_index(drop=True, inplace=True)
exceed_geo
# Out:
#            FinalData.Component  \
# 0                    Air Force
# 1                    Air Force
# 2                    Air Force
# 3                    Air Force
# 4                         Navy
# 5                         Navy
# 6                    Air Force
# 7                    Air Force
# 8                         Army
# 9                    Air Force
# 10                   Air Force
# 11                   Air Force
# 12                   Air Force
# 13                   Air Force
# 14                   Air Force
# 15                   Air Force
# 16                   Air Force
# 17                   Air Force
# 18                   Air Force
# 19                   Air Force
# 20                   Air Force
# 21                   Air Force
# 22                   Air Force
# 23                        Navy
# 24  Formerly Used Defense Site
# 25                        Navy
# 26                        Navy
# 27                   Air Force
# 28                   Air Force
# 29                   Air Force
# 30                   Air Force
# 31                        Army
# 32                        Navy
# 33                   Air Force
# 34                   Air Force
# 35                   Air Force
# 36                   Air Force
# 37                   Air Force
# 38                   Air Force
# 39                        Army
# 40                        Navy
# 41                        Navy
# 42                        Navy
# 43                        Navy
#
#                            FinalData.InstallationName                 State  \
# 0                                  Air Force Plant 44               Arizona
# 1                                          Arnold AFB             Tennessee
# 2                         Avon Park Air Force Reserve               Florida
# 3     Biddle ANGB (formerly Horsham/Willow Grove ANG)          Pennsylvania
# 4                                       Brunswick NAS                 Maine
# 5                                   CID CORRY STATION               Florida
# 6                                         Eielson AFB                Alaska
# 7                                       Ellsworth AFB          South Dakota
# 8                Fort William Henry Harrison /JFHQ MT               Montana
# 9                   Galena Forward Operating Location                Alaska
# 10                                         George AFB            California
# 11                                     Goodfellow AFB                 Texas
# 12                  Great Falls International Airport               Montana
# 13                         Homestead Air Reserve Base               Florida
# 14                                     Hurlburt Field               Florida
# 15                   Joint Base McGuire-Dix-Lakehurst            New Jersey
# 16                                    Little Rock AFB              Arkansas
# 17                                         Loring AFB                 Maine
# 18                                           Luke AFB               Arizona
# 19                                          March AFB            California
# 20                                         Mather AFB            California
# 21                                      McConnell AFB                Kansas
# 22                                 McEntire Air Guard        South Carolina
# 23                            MECHANICSBURG PA NAVICP          Pennsylvania
# 24                            NAVAL AUX LANDING FIELD          Rhode Island
# 25                              NCTAMSLANT DET CUTLER                 Maine
# 26                                      OCEANA VA NAS              Virginia
# 27  Otis ANG (Joint Base Cape Cod -Massachusetts M...         Massachusetts
# 28                                          Pease AFB         New Hampshire
# 29                                       Peterson AFB              Colorado
# 30                                    Plattsburgh AFB              New York
# 31           Presidio of Monterey - Sharpe Army Depot            California
# 32                                 SAUFLEY FLD FL NAS               Florida
# 33                                      Schriever AFB              Colorado
# 34                                          Scott AFB              Illinois
# 35                                Seymour Johnson AFB        North Carolina
# 36                                           Shaw AFB        South Carolina
# 37                                       Sheppard AFB                 Texas
# 14  30.620166  -86.540067   POINT (-86.54007 30.62017)
# 15  40.041267  -74.584368   POINT (-74.58437 40.04127)
# 16  34.911592  -92.146859   POINT (-92.14686 34.91159)
# 17  46.939676  -67.905252   POINT (-67.90525 46.93968)
# 18  33.539951 -112.366482  POINT (-112.36648 33.53995)
# 19  33.898203 -117.263728  POINT (-117.26373 33.89820)
# 20  38.563659 -121.297211  POINT (-121.29721 38.56366)
# 21  37.620787  -97.277092   POINT (-97.27709 37.62079)
# 22  33.922953  -80.800610   POINT (-80.80061 33.92295)
# 23  40.227695  -76.986598   POINT (-76.98660 40.22769)
# 24  41.370278  -71.663056   POINT (-71.66306 41.37028)
# 25  44.649271  -67.285090   POINT (-67.28509 44.64927)
# 26  36.815192  -76.031174   POINT (-76.03117 36.81519)
# 27  41.658201  -70.521583   POINT (-70.52158 41.65820)
# 28  43.080259  -70.821129   POINT (-70.82113 43.08026)
# 29  38.820337 -104.696366  POINT (-104.69637 38.82034)
# 30  44.683551  -73.447904   POINT (-73.44790 44.68355)
# 31  37.853982 -121.265966  POINT (-121.26597 37.85398)
# 32  30.470444  -87.341373   POINT (-87.34137 30.47044)
# 33  38.803380 -104.525640  POINT (-104.52564 38.80338)
# 34  38.541451  -89.853690   POINT (-89.85369 38.54145)
# 35  35.348746  -77.967841   POINT (-77.96784 35.34875)
# 36  33.970000  -80.470000   POINT (-80.47000 33.97000)
# 37  33.976016  -98.500712   POINT (-98.50071 33.97602)
# 38  35.425779  -97.391055   POINT (-97.39105 35.42578)
# 39  38.748428  -77.673877   POINT (-77.67388 38.74843)
# 40  40.204319  -75.067753   POINT (-75.06775 40.20432)
# 41  38.874022  -76.994970   POINT (-76.99497 38.87402)
# 42  48.338638 -122.661501  POINT (-122.66150 48.33864)
# 43  40.198518  -75.145664   POINT (-75.14566 40.19852)

# %%
#removing data for Alaska because it does not properly display
exceed_geo_points = exceed_geo_points[exceed_geo_points.State != 'Alaska']

# %%
#pulling in basemap, outline of states. Commented out due to GitHub issues. 
states = gpd.read_file('tl_2012_us_state.shp')
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
states.head()
# Out:
#    OBJECTID REGION DIVISION STATEFP   STATENS GEOID STUSPS        NAME LSAD  \
# 0         1      4        9      15  01779782    15     HI      Hawaii   00
# 1         2      3        7      05  00068085    05     AR    Arkansas   00
# 2         3      4        8      35  00897535    35     NM  New Mexico   00
# 3         4      4        8      30  00767982    30     MT     Montana   00
# 4         5      1        2      36  01779796    36     NY    New York   00
#
#    MTFCC FUNCSTAT         ALAND        AWATER     INTPTLAT      INTPTLON  \
# 0  G4000        A  1.663425e+10  1.167874e+10  +19.8097670  -155.5061027
# 1  G4000        A  1.347726e+11  2.959210e+09  +34.8955256  -092.4446262
# 2  G4000        A  3.141611e+11  7.564385e+08  +34.4346843  -106.1316181
# 3  G4000        A  3.769636e+11  3.868565e+09  +47.0511771  -109.6348174
# 4  G4000        A  1.220579e+11  1.923885e+10  +42.9133974  -075.5962723
#
#      Shape_Leng    Shape_Area  \
# 0  2.419034e+06  3.268482e+10
# 1  2.656648e+06  2.053261e+11
# 2  2.900368e+06  4.643927e+11
# 3  4.607246e+06  8.201836e+11
# 4  3.212630e+06  2.637702e+11
#
#                                             geometry
# 0  MULTIPOLYGON (((-17361760.204 2164544.588, -17...
# 1  POLYGON ((-10515267.713 4101325.818, -10515269...
# 2  POLYGON ((-12138963.727 4106855.170, -12138964...
# 3  POLYGON ((-12727480.235 5886876.586, -12727567...
# 4  MULTIPOLYGON (((-8866092.533 5160809.769, -886...

# %%
#viewing projection of states basemap to make sure it's WGS84
states.crs
# Out:
# <Projected CRS: PROJCS["Popular Visualisation CRS / Mercator",GEOG ...>
# Name: Popular Visualisation CRS / Mercator
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#only keeping continential US states for ease of viewing
states_50 = states[~states['STUSPS'].isin(['PR','AK','VI','HI','AS','GU','MP'])]
us_map = states_50.boundary.plot(color="#555555", linewidth=1)
us_map.axis('off')
# Out:
# (-14220749.550385, -7123029.871115001, 2624847.4692150005, 6517261.706684997)

# %%
#viewing the projection to make sure it's WGS84, same as the data
states_50.crs
# Out:
# <Projected CRS: PROJCS["Popular Visualisation CRS / Mercator",GEOG ...>
# Name: Popular Visualisation CRS / Mercator
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#ensuring projections of the points are also WGS84
exceed_geo_points.crs = "EPSG:4326" #WGs84 code
#make the same as US map. Should be WSG84, but just in case
exceed_geo_points = exceed_geo_points.to_crs(states_50.crs)

# %%
#typically I run %matplotlib qt to display a map of popout window. Displaying inline instead for GitHub. 
# %matplotlib inline
from adjustText import adjust_text

base = states_50.plot(color='white', edgecolor='grey')

ax = exceed_geo_points.plot(ax=base, marker='o', color='red', markersize=20)

for x, y, label in zip(exceed_geo_points.geometry.x, exceed_geo_points.geometry.y, exceed_geo_points['FinalData.InstallationName']):
    ax.annotate(label, xy=(x, y), xytext=(10, -10), ha='right', fontsize=10, textcoords="offset points") #arrowprops=dict(facecolor='black', shrink=0.05)) # textcoords="offset pixels")

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18,12)
plt.show()
