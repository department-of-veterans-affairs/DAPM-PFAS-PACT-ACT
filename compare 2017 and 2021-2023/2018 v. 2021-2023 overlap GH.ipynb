# %% [markdown]
# ## This code compares Per- and Polyfluoroalkyl Substances (PFAS) concentrations in drinking water on or near military installations collected in 2018 v. 2021-2023.
#
# ### The data was scraped from a publicly available Department of Defense (DOD) website.

# %%
import pandas as pd
import os
from fuzzywuzzy import process # fuzz
import numpy as np


os.chdir(r'C:\Users\OITNYNWilsoS\OneDrive - Department of Veterans Affairs\python\PACT Act - MET\PDF data/')
cwd = os.getcwd()
print("Current working directory is:", cwd)
# Out:
# Current working directory is: C:\Users\OITNYNWilsoS\OneDrive - Department of Veterans Affairs\python\PACT Act - MET\PDF data

# %%
#pull in 2018 data that was scraped from pdf. See repository called "DAPM-PFAS-PDF-scrape" on Department of
#Veterans Affair GitHub. https://github.com/department-of-veterans-affairs/DAPM-PFAS-PDF-scrape
# %store -r
df_2018
df_2018 = df_2018.sort_values('name', ascending=True)
df_2018 = df_2018.reset_index(drop=True)
df_2018.head()
# Out:
#             branch                                 name           state  date  \
# 0             Army        81ST RSC: E. EARLE RIVES AFRC  North Carolina  2017
# 1             Army  99TH RSC MARTINSBURG MEMORIAL USARC   West Virginia  2017
# 2      Navy - BRAC                                AGANA            Guam  2017
# 3  Air Force - ANG                  BARNES ANGB (104TH)   Massachusetts  2017
# 4             Army                       BELMONT ARMORY        Michigan  2017
#
#   number systems tested number above EPA LHA    Results (PFOS/ PFOA)  \
# 0                     1                    1                  <40-90
# 1                     1                    1               0-79/0-71
# 2                    12                    5                88 - 410
# 3                     1                    1  43-160 ppt (PFOS+PFOA)
# 4                     1                    1                 86-96.8
#
#                  Actions Taken as of August 31, 2017  \
# 0  PFOS per 2014 Consumer Confidence Report. The ...
# 1  The results reported were the range of PFOS/PF...
# 2  Sampling conducted by Guam Waterworks Authorit...
# 3  Base obtains water from Westfield Water Dept. ...
# 4  MIARNG spoke with potential responsible party ...
#
#                            Actions Planned to reduce purveyor on or off base  \
# 0                                                NaN  non-DOD             on
# 1                                                NaN  non-DOD             on
# 2                                                NaN  non-DOD            off
# 3  Water sources will continue to be sampled for ...  non-DOD             on
# 4  MIARNG is waiting for response from PRP, explo...      DOD             on
#
#    results    analyte
# 0     90.0        NaN
# 1     79.0        NaN
# 2    410.0        NaN
# 3    160.0  PFOA+PFOS
# 4     96.8        NaN

# %%
#pull in 2021-2023 data scraped from website. See repository called "DAPM-PFAS-web-scrape-and-map" on Department of
#Veterans Affair GitHub. https://github.com/department-of-veterans-affairs/DAPM-PFAS-web-scrape-and-map
# %store -r 
map_70 
map_70.head()
# Out:
#             state     branch                         name        date  \
# 0         Arizona  Air Force           AIR FORCE PLANT 44  2022-10-11
# 1       Tennessee  Air Force                   ARNOLD AFB  2021-12-14
# 2         Florida  Air Force  AVON PARK AIR FORCE RESERVE  2021-12-20
# 3  South Carolina       Navy             BEAUFORT SC MCAS  2022-12-09
# 4      Washington       Navy        BREMERTON  WA NAVBASE  2022-05-03
#
#     method analyte result  MCLs  exceedance LimitDetect units qualifier  \
# 0  QSM_B15    PFOS   29.2    70       False           4  ng/L
# 1  QSM_B15    PFOA   40.9    70       False         4.2  ng/L
# 2  QSM_B15    PFOS   40.3    70       False           4  ng/L
# 3    537.1    PFOA   1.49    70       False        1.19  ng/L         J
# 4    537.1    PFOA  0.478    70       False        1.12  ng/L         J
#
#   TreatSystem    TreatStatus   latitude   longitude
# 0         Yes  pre-treatment  32.221743 -110.926479
# 1          No                 35.398810  -86.078066
# 2          No                 27.595670  -81.506186
# 3          No                 32.475964  -80.726366
# 4          No                 47.711998 -122.714478

# %%
#searching for base names in the 2021-2023 dataframe for matching later
#JB Lewis McChord is in both dataframes. However, one is for Yakima Training Center (2022) and the other is for 
#"Fort Lewis Cantonment". I think these might be far from each other, so should remain unmatched. 

pd.set_option('display.max_colwidth', None)
mask = map_70['name'].str.contains('GRAYLING')
result = map_70[mask]
result
# Out:
#        state branch                                                  name  \
# 39  Michigan   Army  MTC-H CAMP GRAYLING AIRFIELD (INSTALLATION-WIDE PAI)
#
#           date   method analyte result  MCLs  exceedance LimitDetect units  \
# 39  2022-05-10  QSM_B15    PFOS   1.42    70       False        1.97  ng/L
#
#    qualifier TreatSystem TreatStatus   latitude  longitude
# 39         J          No              44.630811 -84.777406

# %%
#searching for base names in the 2018 dataframe for matching later
pd.set_option('display.max_colwidth', None)
mask_2018 = df_2018['name'].str.contains('GRAYLING')
result_2018 = df_2018[mask_2018]
result_2018
# Out:
#    branch                                          name     state  date  \
# 20   Army  CAMP GRAYLING JOINT MANEUVER TRAINING CENTER  Michigan  2017
#
#    number systems tested number above EPA LHA Results (PFOS/ PFOA)  \
# 20                   188                    4               70-188
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           Actions Taken as of August 31, 2017  \
# 20  Residential drinking water wells were sampled downgradient of the Camp Grayling Airfield where groundwater samples indicated PFOS/PFOA results > LHA. The Michigan DHHS paid for aquasana drinking water filter systems under counter faucet 3 stage max flow and local Health Dept. had them installed in any home with PFOS/PFOA detections. 42 systems have been installed. An additional 14, purchased by local Health were installed by home owners.
#
#                                                                                                                                                                                                                                                                                                                                                 Actions Planned to reduce  \
# 20  The Michigan DEQ has been funded to conduct off post residential sampling and hydrologic study. The DHHS and local Health Dept. will continue to purchase filter systems and install them as needed or requested by home owners. Michigan DEQ is continuing to expand the area of drinking water sampling to the east side of the airfield. Numbers of wells are TBD.
#
#    purveyor on or off base  results analyte
# 20  non-DOD            off    188.0     NaN

# %%
#remove punctuation from name column to allow for better matching
df_2018['name'] = df_2018['name'] .apply(lambda x: x.replace('(','').replace(')','')) 
#rename installation names to allow for better matching
df_2018['name'] = df_2018['name'].str.replace('CAMP GRAYLING JOINT MANEUVER TRAINING CENTER','CAMP GRAYLING MTC')
df_2018['name'] = df_2018['name'].str.replace('NAS WHITING FIELD MAIN BASE','WHITING FLD FL NAS')
df_2018['name'] = df_2018['name'].str.replace('HORSHAM AGS AGS 111TH','BIDDLE ANGB')
df_2018['name'] = df_2018['name'].str.replace('NAS WHIDBEY ISLAND - AULT FIELD PRIVATE','WHIDBEY IS WA NAS AULT FIELD')
df_2018['name'] = df_2018['name'].str.replace('NAS WHIDBEY ISLAND - OLF COUPEVILLE PRIVATEE','WHIDBEY IS WA NAS COUPEVILLE')
df_2018['name'] = df_2018['name'].str.replace('NAS OCEANA - NALF FENTRESS','OCEANA VA NAS')

df_2018.head()
# Out:
#                branch                                 name          state  \
# 0                USMC             MCB CAMP PENDLETON SOUTH     California
# 1                Army  99TH RSC MARTINSBURG MEMORIAL USARC  West Virginia
# 2                Army                             EL CAMPO          Texas
# 3                Army                     SOTO CANO AB, HN       Honduras
# 4  Air Force - ACTIVE                       NEW BOSTON AFS  New Hampshire
#
#    date number systems tested number above EPA LHA  \
# 0  2017                     1                    1
# 1  2017                     1                    1
# 2  2017                     1                    1
# 3  2017                     1                    1
# 4  2017                     2                    1
#
#                 Results (PFOS/ PFOA)  \
# 0                                 77
# 1                          0-79/0-71
# 2                                 79
# 3  PFOA + PFOS combined = 72.5- 82.9
# 4              13-83 ppt (PFOS+PFOA)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Actions Taken as of August 31, 2017  \
# 0                                                                                                                                                                     One sample exceeded the PFOS/PFOA combined Health Advisories Level. -The affected reservoir was drained and replaced with water from another source. -Resampling confirmed levels below the Health Advisories Level in the current water supply and levels slightly above the Health Advisories Level in the well taken out of service. Installation will continue to monitor the system.
# 1                                                                                                                                                                                                                                                                                                                                                                                  The results reported were the range of PFOS/PFOA in 2014, and the public water system is not reporting exceedances to users due to compliance averaging of all test results.
# 2                                                                                                                                                                                                                                                                                                                                            Well is designated as non-potable. Bottled water is being provided for an alternate drinking water supply. A Granular Activated Carbon Filter System installed and confirmation sampling conducted in August 2017.
# 3  Initial, confirmatory and subsequent sampling conducted at multiple wells (Dec 16-Feb 17). Bottled water is routinely used throughout the installation, except at DFAC (for ice, coffee, tea, etc.); larger carbon filter installed to accommodate the flow rate servicing DFAC; subsequent confirmation sample indicated PFOA/PFOS <LHA at DFAC prep sink; except at DFAC, bottled water will remain the norm for consumption. Implemented recurring sampling/analysis. Consumer notification conducted 09 Mar 17. Implemented recurring sampling/analysis.
# 4                                                                                                                                                                                                                                                                                                                                                                                        Drinking water sampling and analysis. DW well above the EPA LHAs has been shut down. The AF is conducting quarterly sampling for the operational drinking water wells.
#
#                                                                                                                                                                                                                                                                                      Actions Planned to reduce  \
# 0                                                                                                                                                                                                                                                            Installation will continue to monitor the system.
# 1                                                                                                                                                                                                                                                                                                          NaN
# 2  Additional sampling will be conducted in November 2017 and February 2018 to determine if filtration system is reducing drinking water below the LHA. If sampling results determine the water source is below the LHA, bottled water usage will be discontinued and the water well reestablished as potable.
# 3                                                                                                                                                                                                                                                                                                          NaN
# 4                                                                                                                                                                                       Project has been awarded to add Activated Carbon to impacted DW well to fix PFOS/PFOA. Quarterly testing will continue
#
#   purveyor on or off base  results    analyte
# 0      DOD             on     77.0        NaN
# 1  non-DOD             on     79.0        NaN
# 2      DOD             on     79.0        NaN
# 3      DOD             on     82.9  PFOA+PFOS
# 4      DOD             on     83.0  PFOA+PFOS

# %%
#rename installation names to allow for better matching
pd.set_option('display.max_rows', None)
map_70['name'] = map_70['name'] .apply(lambda x: x.replace('(','').replace(')','')) 
map_70['name'] = map_70['name'].str.replace('WILLOW GROVE NASJRB','WILLOW GROVE')
map_70['name'] = map_70['name'].str.replace('WARMINSTER NAWC AD', 'WARMINSTER')
map_70['name'] = map_70['name'].str.replace('MTC-H CAMP GRAYLING AIRFIELD INSTALLATION-WIDE PAI', 'CAMP GRAYLING MTC')
map_70.head()
# Out:
#             state     branch                         name        date  \
# 0         Arizona  Air Force           AIR FORCE PLANT 44  2022-10-11
# 1       Tennessee  Air Force                   ARNOLD AFB  2021-12-14
# 2         Florida  Air Force  AVON PARK AIR FORCE RESERVE  2021-12-20
# 3  South Carolina       Navy             BEAUFORT SC MCAS  2022-12-09
# 4      Washington       Navy        BREMERTON  WA NAVBASE  2022-05-03
#
#     method analyte result  MCLs  exceedance LimitDetect units qualifier  \
# 0  QSM_B15    PFOS   29.2    70       False           4  ng/L
# 1  QSM_B15    PFOA   40.9    70       False         4.2  ng/L
# 2  QSM_B15    PFOS   40.3    70       False           4  ng/L
# 3    537.1    PFOA   1.49    70       False        1.19  ng/L         J
# 4    537.1    PFOA  0.478    70       False        1.12  ng/L         J
#
#   TreatSystem    TreatStatus   latitude   longitude
# 0         Yes  pre-treatment  32.221743 -110.926479
# 1          No                 35.398810  -86.078066
# 2          No                 27.595670  -81.506186
# 3          No                 32.475964  -80.726366
# 4          No                 47.711998 -122.714478

# %%
#copy to use the dataframe in another notebook
#map_70_rename = map_70.copy()
#%store map_70_rename

# %%
#calculate similarity scores for both datasets (2018 / pdf and 2021-2023 / webscraped)
name_2018 = []
similarity = []
for i in map_70.name:
        ratio = process.extract(i, df_2018.name, limit=1)
        name_2018.append(ratio[0][0])
        similarity.append(ratio[0][1])
map_70['name_2018'] = pd.Series(name_2018)
map_70['name_2018'] = map_70['name_2018']
map_70['similarity'] = pd.Series(similarity)
map_70.head()
# Out:
#             state     branch                         name        date  \
# 0         Arizona  Air Force           AIR FORCE PLANT 44  2022-10-11
# 1       Tennessee  Air Force                   ARNOLD AFB  2021-12-14
# 2         Florida  Air Force  AVON PARK AIR FORCE RESERVE  2021-12-20
# 3  South Carolina       Navy             BEAUFORT SC MCAS  2022-12-09
# 4      Washington       Navy        BREMERTON  WA NAVBASE  2022-05-03
#
#     method analyte result  MCLs  exceedance LimitDetect units qualifier  \
# 0  QSM_B15    PFOS   29.2    70       False           4  ng/L
# 1  QSM_B15    PFOA   40.9    70       False         4.2  ng/L
# 2  QSM_B15    PFOS   40.3    70       False           4  ng/L
# 3    537.1    PFOA   1.49    70       False        1.19  ng/L         J
# 4    537.1    PFOA  0.478    70       False        1.12  ng/L         J
#
#   TreatSystem    TreatStatus   latitude   longitude  \
# 0         Yes  pre-treatment  32.221743 -110.926479
# 1          No                 35.398810  -86.078066
# 2          No                 27.595670  -81.506186
# 3          No                 32.475964  -80.726366
# 4          No                 47.711998 -122.714478
#
#                                                                             name_2018  \
# 0                                                              FORMER PLATTSBURGH AFB
# 1                                                                   MOUNTAIN HOME AFB
# 2  MARINE FORCES RESERVE MARFORRES-MARINE CORPS RESERVE TRAINING CENTER MCRTC STEWART
# 3                                             JB LEWIS-MCCHORD: FORT LEWIS CANTONMENT
# 4                                                                       OCEANA VA NAS
#
#    similarity
# 0          52
# 1          86
# 2          86
# 3          50
# 4          56

# %%
#keep only the scores greater than or equal to 87. Anything less has noise.
map_70_87 = map_70[map_70["similarity"] >= 87]

map_70_87 = map_70_87.drop(['method', 
                            'LimitDetect',
                            'qualifier',
                            'TreatSystem',
                            'TreatStatus',
                            'latitude',
                            'longitude'], axis=1)
map_70_87.head()
# Out:
#            state     branch                                           name  \
# 5   Pennsylvania  Air Force  BIDDLE ANGB FORMERLY HORSHAM/WILLOW GROVE ANG
# 13      Delaware  Air Force                                      DOVER AFB
# 15        Alaska  Air Force                                    EIELSON AFB
# 16  South Dakota  Air Force                                  ELLSWORTH AFB
# 17    Washington  Air Force                                  FAIRCHILD AFB
#
#           date analyte result  MCLs  exceedance units      name_2018  \
# 5   2022-01-27    PFOS   26.0    70       False  ng/L    BIDDLE ANGB
# 13  2022-01-22    PFOS    nan    70       False  ng/L      DOVER AFB
# 15  2022-06-29    PFOS    9.0    70       False  ng/L    EIELSON AFB
# 16  2022-03-14    PFOS  342.0    70        True  ng/L  ELLSWORTH AFB
# 17  2022-05-31    PFOA    2.9    70       False  ng/L  FAIRCHILD AFB
#
#     similarity
# 5           90
# 13         100
# 15         100
# 16         100
# 17         100

# %%
#select columns with data for merging
df_2018_select = df_2018[['name','analyte','results']]
df_2018_select = df_2018_select.rename({'name':'name_2018',
                                        'analyte':'analyte_2018',
                                        'results':'results_2018'}, axis=1)

df_2018_select.head()
# Out:
#                              name_2018 analyte_2018  results_2018
# 0             MCB CAMP PENDLETON SOUTH          NaN          77.0
# 1  99TH RSC MARTINSBURG MEMORIAL USARC          NaN          79.0
# 2                             EL CAMPO          NaN          79.0
# 3                     SOTO CANO AB, HN    PFOA+PFOS          82.9
# 4                       NEW BOSTON AFS    PFOA+PFOS          83.0

# %%
# merge dataframes to compare concentrations of installations found in both the 2018 and 2021-2023 dataframes
map_70_87_results = map_70_87.merge(df_2018_select,on=['name_2018'],how='left')
map_70_87_results = map_70_87_results[['state',
                                       'branch',  
                                       'similarity',
                                       'name_2018',
                                       'analyte_2018',
                                       'results_2018',
                                       'name',
                                       'date',
                                       'analyte',
                                       'result',
                                       'MCLs',
                                       'exceedance',
                                       'units']]

map_70_87_results = map_70_87_results.rename(columns={'name': 'name_21_23',
                                                      'analyte':'analyte_21_23',
                                                      'result':'results_21_23', 
                                                      'exceedance':'exceedance_21_23'})

#convert nan string to numpy nan
map_70_87_results['results_21_23'] = map_70_87_results['results_21_23'].replace('nan', np.nan)
#convert column to numeric
map_70_87_results['results_21_23'] = pd.to_numeric(map_70_87_results['results_21_23'])

map_70_87_results
# Out:
#             state     branch  similarity                          name_2018  \
# 0    Pennsylvania  Air Force          90                        BIDDLE ANGB
# 1    Pennsylvania  Air Force          90                        BIDDLE ANGB
# 2        Delaware  Air Force         100                          DOVER AFB
# 3          Alaska  Air Force         100                        EIELSON AFB
# 4          Alaska  Air Force         100                        EIELSON AFB
# 5    South Dakota  Air Force         100                      ELLSWORTH AFB
# 6      Washington  Air Force         100                      FAIRCHILD AFB
# 7      New Jersey  Air Force          98  JOINT BASE MCGUIRE- DIX-LAKEHURST
# 8        Michigan  Air Force          90               FORMER KI SAWYER AFB
# 9        Michigan       Army         100                  CAMP GRAYLING MTC
# 10     California  Air Force          90                   FORMER MARCH AFB
# 11     California  Air Force          90                  FORMER MATHER AFB
# 12       Virginia       Navy         100                      OCEANA VA NAS
# 13       Virginia       Navy         100                      OCEANA VA NAS
# 14  Massachusetts  Air Force          90                JOINT BASE CAPE COD
# 15  New Hampshire  Air Force          90                   FORMER PEASE AFB
# 16       New York  Air Force          95             FORMER PLATTSBURGH AFB
# 17     Washington       Navy          90       WHIDBEY IS WA NAS AULT FIELD
# 18        Florida       Navy         100                 WHITING FLD FL NAS
# 19   Pennsylvania       Navy          90                  WARMINSTER PUBLIC
# 20   Pennsylvania       Navy          90                WILLOW GROVE PUBLIC
# 21       Michigan  Air Force          90               FORMER WURTSMITH AFB
#
#    analyte_2018  results_2018  \
# 0     PFOA+PFOS         290.0
# 1     PFOA+PFOS        1870.0
# 2     PFOA+PFOS          91.0
# 3     PFOA+PFOS         111.0
# 4     PFOA+PFOS        2222.0
# 5     PFOA+PFOS         182.0
# 6     PFOA+PFOS        5700.0
# 7     PFOA+PFOS        1688.0
# 8     PFOA+PFOS        3651.0
# 9           NaN         188.0
# 10    PFOA+PFOS         168.0
# 11    PFOA+PFOS         193.0
# 12          NaN        1660.0
# 13          NaN        4900.0
# 14    PFOA+PFOS         488.0
# 15    PFOA+PFOS         870.0
# 16    PFOA+PFOS         412.0
# 17          NaN        3823.0
# 18          NaN         259.0
# 19          NaN        1300.0
# 20          NaN        1000.0
# 21    PFOA+PFOS        2923.0
#
#                                                           name_21_23  \
# 0                      BIDDLE ANGB FORMERLY HORSHAM/WILLOW GROVE ANG
# 1                      BIDDLE ANGB FORMERLY HORSHAM/WILLOW GROVE ANG
# 2                                                          DOVER AFB
# 3                                                        EIELSON AFB
# 4                                                        EIELSON AFB
# 5                                                      ELLSWORTH AFB
# 6                                                      FAIRCHILD AFB
# 7                                   JOINT BASE MCGUIRE-DIX-LAKEHURST
# 8                                                      KI SAWYER AFB
# 9                                                  CAMP GRAYLING MTC
# 10                                                         MARCH AFB
# 11                                                        MATHER AFB
# 12                                                     OCEANA VA NAS
# 13                                                     OCEANA VA NAS
# 14  OTIS ANG JOINT BASE CAPE COD -MASSACHUSETTS MILITARY RESERVATION
# 15                                                         PEASE AFB
# 16                                                   PLATTSBURGH AFB
# 17                                                 WHIDBEY IS WA NAS
# 18                                                WHITING FLD FL NAS
# 19                                                        WARMINSTER
# 20                                                      WILLOW GROVE
# 21                                                     WURTSMITH AFB
#
#           date analyte_21_23  results_21_23  MCLs  exceedance_21_23 units
# 0   2022-01-27          PFOS          26.00    70             False  ng/L
# 1   2022-01-27          PFOS          26.00    70             False  ng/L
# 2   2022-01-22          PFOS            NaN    70             False  ng/L
# 3   2022-06-29          PFOS           9.00    70             False  ng/L
# 4   2022-06-29          PFOS           9.00    70             False  ng/L
# 5   2022-03-14          PFOS         342.00    70              True  ng/L
# 6   2022-05-31          PFOA           2.90    70             False  ng/L
# 7   2021-11-09          PFOS          83.00    70              True  ng/L
# 8   2022-07-13          PFOS            NaN    70             False  ng/L
# 9   2022-05-10          PFOS           1.42    70             False  ng/L
# 10  2022-01-03          PFOS         220.00    70              True  ng/L
# 11  2021-11-30          PFOS          36.00    70             False  ng/L
# 12  2021-10-04          PFOA           5.67    70             False  ng/L
# 13  2021-10-04          PFOA           5.67    70             False  ng/L
# 14  2022-01-19          PFOA          11.00    70             False  ng/L
# 15  2022-04-19          PFOS          96.00    70              True  ng/L
# 16  2021-11-18          PFOS         110.00    70              True  ng/L
# 17  2021-09-16          PFOA         208.00    70              True  ng/L
# 18  2021-08-23          PFOA           0.82    70             False  ng/L
# 19  2022-07-12          PFOA          27.30    70             False  ng/L
# 20  2022-06-29          PFOA          21.70    70             False  ng/L
# 21  2023-09-26          PFOS            NaN    70             False  ng/L

# %%
#map_70_87_results.to_csv(r"C:\Users\OITNYNWilsoS\OneDrive - Department of Veterans Affairs\PACT Act\MET\deliverables\compare_2018_and_21_23.csv", float_format='{:f}'.format, encoding='utf-8', index=False)

# %%
#check datatype to make sure it's numeric or styling in cell block below won't work
map_70_87_results['results_21_23'].dtypes
# Out:
# dtype('float64')

# %%
#highlight results where the 2021-2023 concentrations are greater than the 2018

def highlight(table):
    if table.results_21_23 >= table.results_2018:
        return['background-color: yellow']*len(table)
    else:
        return['background-color: white']*len(table)
    
    
map_70_87_results = map_70_87_results.style.apply(highlight, axis = 1).format(precision=1)

map_70_87_results
# Out:
# <style type="text/css">
# #T_c7bce_row0_col0, #T_c7bce_row0_col1, #T_c7bce_row0_col2, #T_c7bce_row0_col3, #T_c7bce_row0_col4, #T_c7bce_row0_col5, #T_c7bce_row0_col6, #T_c7bce_row0_col7, #T_c7bce_row0_col8, #T_c7bce_row0_col9, #T_c7bce_row0_col10, #T_c7bce_row0_col11, #T_c7bce_row0_col12, #T_c7bce_row1_col0, #T_c7bce_row1_col1, #T_c7bce_row1_col2, #T_c7bce_row1_col3, #T_c7bce_row1_col4, #T_c7bce_row1_col5, #T_c7bce_row1_col6, #T_c7bce_row1_col7, #T_c7bce_row1_col8, #T_c7bce_row1_col9, #T_c7bce_row1_col10, #T_c7bce_row1_col11, #T_c7bce_row1_col12, #T_c7bce_row2_col0, #T_c7bce_row2_col1, #T_c7bce_row2_col2, #T_c7bce_row2_col3, #T_c7bce_row2_col4, #T_c7bce_row2_col5, #T_c7bce_row2_col6, #T_c7bce_row2_col7, #T_c7bce_row2_col8, #T_c7bce_row2_col9, #T_c7bce_row2_col10, #T_c7bce_row2_col11, #T_c7bce_row2_col12, #T_c7bce_row3_col0, #T_c7bce_row3_col1, #T_c7bce_row3_col2, #T_c7bce_row3_col3, #T_c7bce_row3_col4, #T_c7bce_row3_col5, #T_c7bce_row3_col6, #T_c7bce_row3_col7, #T_c7bce_row3_col8, #T_c7bce_row3_col9, #T_c7bce_row3_col10, #T_c7bce_row3_col11, #T_c7bce_row3_col12, #T_c7bce_row4_col0, #T_c7bce_row4_col1, #T_c7bce_row4_col2, #T_c7bce_row4_col3, #T_c7bce_row4_col4, #T_c7bce_row4_col5, #T_c7bce_row4_col6, #T_c7bce_row4_col7, #T_c7bce_row4_col8, #T_c7bce_row4_col9, #T_c7bce_row4_col10, #T_c7bce_row4_col11, #T_c7bce_row4_col12, #T_c7bce_row6_col0, #T_c7bce_row6_col1, #T_c7bce_row6_col2, #T_c7bce_row6_col3, #T_c7bce_row6_col4, #T_c7bce_row6_col5, #T_c7bce_row6_col6, #T_c7bce_row6_col7, #T_c7bce_row6_col8, #T_c7bce_row6_col9, #T_c7bce_row6_col10, #T_c7bce_row6_col11, #T_c7bce_row6_col12, #T_c7bce_row7_col0, #T_c7bce_row7_col1, #T_c7bce_row7_col2, #T_c7bce_row7_col3, #T_c7bce_row7_col4, #T_c7bce_row7_col5, #T_c7bce_row7_col6, #T_c7bce_row7_col7, #T_c7bce_row7_col8, #T_c7bce_row7_col9, #T_c7bce_row7_col10, #T_c7bce_row7_col11, #T_c7bce_row7_col12, #T_c7bce_row8_col0, #T_c7bce_row8_col1, #T_c7bce_row8_col2, #T_c7bce_row8_col3, #T_c7bce_row8_col4, #T_c7bce_row8_col5, #T_c7bce_row8_col6, #T_c7bce_row8_col7, #T_c7bce_row8_col8, #T_c7bce_row8_col9, #T_c7bce_row8_col10, #T_c7bce_row8_col11, #T_c7bce_row8_col12, #T_c7bce_row9_col0, #T_c7bce_row9_col1, #T_c7bce_row9_col2, #T_c7bce_row9_col3, #T_c7bce_row9_col4, #T_c7bce_row9_col5, #T_c7bce_row9_col6, #T_c7bce_row9_col7, #T_c7bce_row9_col8, #T_c7bce_row9_col9, #T_c7bce_row9_col10, #T_c7bce_row9_col11, #T_c7bce_row9_col12, #T_c7bce_row11_col0, #T_c7bce_row11_col1, #T_c7bce_row11_col2, #T_c7bce_row11_col3, #T_c7bce_row11_col4, #T_c7bce_row11_col5, #T_c7bce_row11_col6, #T_c7bce_row11_col7, #T_c7bce_row11_col8, #T_c7bce_row11_col9, #T_c7bce_row11_col10, #T_c7bce_row11_col11, #T_c7bce_row11_col12, #T_c7bce_row12_col0, #T_c7bce_row12_col1, #T_c7bce_row12_col2, #T_c7bce_row12_col3, #T_c7bce_row12_col4, #T_c7bce_row12_col5, #T_c7bce_row12_col6, #T_c7bce_row12_col7, #T_c7bce_row12_col8, #T_c7bce_row12_col9, #T_c7bce_row12_col10, #T_c7bce_row12_col11, #T_c7bce_row12_col12, #T_c7bce_row13_col0, #T_c7bce_row13_col1, #T_c7bce_row13_col2, #T_c7bce_row13_col3, #T_c7bce_row13_col4, #T_c7bce_row13_col5, #T_c7bce_row13_col6, #T_c7bce_row13_col7, #T_c7bce_row13_col8, #T_c7bce_row13_col9, #T_c7bce_row13_col10, #T_c7bce_row13_col11, #T_c7bce_row13_col12, #T_c7bce_row14_col0, #T_c7bce_row14_col1, #T_c7bce_row14_col2, #T_c7bce_row14_col3, #T_c7bce_row14_col4, #T_c7bce_row14_col5, #T_c7bce_row14_col6, #T_c7bce_row14_col7, #T_c7bce_row14_col8, #T_c7bce_row14_col9, #T_c7bce_row14_col10, #T_c7bce_row14_col11, #T_c7bce_row14_col12, #T_c7bce_row15_col0, #T_c7bce_row15_col1, #T_c7bce_row15_col2, #T_c7bce_row15_col3, #T_c7bce_row15_col4, #T_c7bce_row15_col5, #T_c7bce_row15_col6, #T_c7bce_row15_col7, #T_c7bce_row15_col8, #T_c7bce_row15_col9, #T_c7bce_row15_col10, #T_c7bce_row15_col11, #T_c7bce_row15_col12, #T_c7bce_row16_col0, #T_c7bce_row16_col1, #T_c7bce_row16_col2, #T_c7bce_row16_col3, #T_c7bce_row16_col4, #T_c7bce_row16_col5, #T_c7bce_row16_col6, #T_c7bce_row16_col7, #T_c7bce_row16_col8, #T_c7bce_row16_col9, #T_c7bce_row16_col10, #T_c7bce_row16_col11, ...
#   background-color: white;
# }
# #T_c7bce_row5_col0, #T_c7bce_row5_col1, #T_c7bce_row5_col2, #T_c7bce_row5_col3, #T_c7bce_row5_col4, #T_c7bce_row5_col5, #T_c7bce_row5_col6, #T_c7bce_row5_col7, #T_c7bce_row5_col8, #T_c7bce_row5_col9, #T_c7bce_row5_col10, #T_c7bce_row5_col11, #T_c7bce_row5_col12, #T_c7bce_row10_col0, #T_c7bce_row10_col1, #T_c7bce_row10_col2, #T_c7bce_row10_col3, #T_c7bce_row10_col4, #T_c7bce_row10_col5, #T_c7bce_row10_col6, #T_c7bce_row10_col7, #T_c7bce_row10_col8, #T_c7bce_row10_col9, #T_c7bce_row10_col10, #T_c7bce_row10_col11, #T_c7bce_row10_col12 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c7bce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7bce_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_c7bce_level0_col1" class="col_heading level0 col1" >branch</th>
#       <th id="T_c7bce_level0_col2" class="col_heading level0 col2" >similarity</th>
#       <th id="T_c7bce_level0_col3" class="col_heading level0 col3" >name_2018</th>
#       <th id="T_c7bce_level0_col4" class="col_heading level0 col4" >analyte_2018</th>
#       <th id="T_c7bce_level0_col5" class="col_heading level0 col5" >results_2018</th>
#       <th id="T_c7bce_level0_col6" class="col_heading level0 col6" >name_21_23</th>
#       <th id="T_c7bce_level0_col7" class="col_heading level0 col7" >date</th>
#       <th id="T_c7bce_level0_col8" class="col_heading level0 col8" >analyte_21_23</th>
#       <th id="T_c7bce_level0_col9" class="col_heading level0 col9" >results_21_23</th>
#       <th id="T_c7bce_level0_col10" class="col_heading level0 col10" >MCLs</th>
#       <th id="T_c7bce_level0_col11" class="col_heading level0 col11" >exceedance_21_23</th>
#       <th id="T_c7bce_level0_col12" class="col_heading level0 col12" >units</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7bce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7bce_row0_col0" class="data row0 col0" >Pennsylvania</td>
#       <td id="T_c7bce_row0_col1" class="data row0 col1" >Air Force</td>
#       <td id="T_c7bce_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_c7bce_row0_col3" class="data row0 col3" >BIDDLE ANGB</td>
#       <td id="T_c7bce_row0_col4" class="data row0 col4" >PFOA+PFOS</td>
#       <td id="T_c7bce_row0_col5" class="data row0 col5" >290.0</td>
#       <td id="T_c7bce_row0_col6" class="data row0 col6" >BIDDLE ANGB FORMERLY HORSHAM/WILLOW GROVE ANG</td>
#       <td id="T_c7bce_row0_col7" class="data row0 col7" >2022-01-27</td>
#       <td id="T_c7bce_row0_col8" class="data row0 col8" >PFOS</td>
